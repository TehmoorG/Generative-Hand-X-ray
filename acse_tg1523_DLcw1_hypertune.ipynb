# %% [markdown]
# <img src="https://drive.google.com/uc?id=1DvKhAzLtk-Hilu7Le73WAOz2EBR5d41G" width="500"/>
#
# ---

# %% [markdown]
# ### ***Name***: [Tehmoor Gull]
# ### ***username***: [acse_tg1523]
# ### ***CID***: [02538824]
#
#
# You can save this notebook in Colab by clicking `File` from the top menu, and then selecting `Download --> Download .ipynb`
#
# Make sure that when you save your notebook you have all the cells executed and you can see the outputs (livelossplot graphs, etc)

# %% [markdown]
# ## Hyperparameter tunning notebook
#
# Explain the steps and tests you do.
#
# Organise it well to show how the data you present here has helped you design your final network hyperparameters (that you will use for the final training in the `yourusername_DLcw1_clean.ipynb` notebook).

# %% [markdown]
# While not as efficient. I am going to change the code to be able to accept hyperparameters in this file. Once I get the best hyper parameters I will apply them in the other notebook. I am copying most of the code except my implementation of the VAE here is more flexible for hyperparameters.

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Standard libraries
import os
import time
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# PyTorch related imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# Additional utilities
from tqdm import tqdm
from sklearn.model_selection import train_test_split
import itertools


def set_device(device="cpu", idx=0):
    if device != "cpu":
        if torch.cuda.device_count() > idx and torch.cuda.is_available():
            print("Cuda installed! Running on GPU {} {}!".format(idx, torch.cuda.get_device_name(idx)))
            device="cuda:{}".format(idx)
        elif torch.cuda.device_count() > 0 and torch.cuda.is_available():
            print("Cuda installed but only {} GPU(s) available! Running on GPU 0 {}!".format(torch.cuda.device_count(), torch.cuda.get_device_name()))
            device="cuda:0"
        else:
            device="cpu"
            print("No GPU available! Running on CPU")
    return device

device = set_device("cuda")
print(device)
# Out:
# Cuda installed! Running on GPU 0 Tesla V100-SXM2-16GB!
# cuda:0

# %%
class CustomHandDataset(Dataset):
    def __init__(self, image_paths, transform=None):
        self.image_paths = image_paths
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = Image.open(img_path).convert('L')  # Convert to grayscale
        if self.transform:
            image = self.transform(image)
        return image

# %%
# Define transformations including resize to 64x64
transform = transforms.Compose([
    # transforms.Resize((64, 64)),  # Resize images to 64x64
    transforms.ToTensor(),  # Convert to tensor
    transforms.Normalize([0.5], [0.5])  # Normalize to (-1, 1) range
])

# Get all image paths

image_dir = 'drive/MyDrive/real_hands'


image_paths = [os.path.join(image_dir, img) for img in os.listdir(image_dir) if img.endswith('.jpeg')]  # List of all image paths

# Split the paths into train and test sets
train_paths, test_paths = train_test_split(image_paths, test_size=0.2, random_state=42)  # 80-20 split

# Create instances of the dataset with the new transform
train_dataset = CustomHandDataset(train_paths, transform=transform)
test_dataset = CustomHandDataset(test_paths, transform=transform)



# Now you can use train_loader and test_loader in your training and evaluation loops.

# %% [markdown]
# Upto now I have copied the code but here is where i changed my class to be more suitable for hyperparamter tuning. I did this because it will make the main notebook less complicated instead of having all the hyperparameters become arguments etc.

# %%
class VAE(nn.Module):
    def __init__(self, conv_channels=[32, 64, 128, 256], fc_size=128, latent_dim=128):
        super(VAE, self).__init__()
        self.conv_channels = conv_channels
        # Assume conv_channels = [32, 64, 128, 256]
        # Encoder layers
        self.conv1 = nn.Conv2d(1, conv_channels[0], kernel_size=4, stride=2, padding=1)  # Output: 16x16
        self.conv2 = nn.Conv2d(conv_channels[0], conv_channels[1], kernel_size=4, stride=2, padding=1)  # Output: 8x8
        self.conv3 = nn.Conv2d(conv_channels[1], conv_channels[2], kernel_size=4, stride=2, padding=1)  # Output: 4x4
        self.conv4 = nn.Conv2d(conv_channels[2], conv_channels[3], kernel_size=4, stride=2, padding=1)  # Output: 2x2

        self.fc1 = nn.Linear(conv_channels[3] * 2 * 2, latent_dim)  # Output size: mu
        self.fc2 = nn.Linear(conv_channels[3] * 2 * 2, latent_dim)  # Output size: logvar

        # Decoder layers
        self.fc3 = nn.Linear(latent_dim, conv_channels[3] * 2 * 2)  # Match to the output of the encoder
        self.deconv1 = nn.ConvTranspose2d(conv_channels[3], conv_channels[2], kernel_size=4, stride=2, padding=1)  # Output: 4x4
        self.deconv2 = nn.ConvTranspose2d(conv_channels[2], conv_channels[1], kernel_size=4, stride=2, padding=1)  # Output: 8x8
        self.deconv3 = nn.ConvTranspose2d(conv_channels[1], conv_channels[0], kernel_size=4, stride=2, padding=1)  # Output: 16x16
        self.deconv4 = nn.ConvTranspose2d(conv_channels[0], 1, kernel_size=4, stride=2, padding=1)  # Output: 32x32


    def encode(self, x):
        h1 = F.relu(self.conv1(x))
        h2 = F.relu(self.conv2(h1))
        h3 = F.relu(self.conv3(h2))
        h4 = F.relu(self.conv4(h3))
        h4_flattened = h4.view(-1, self.conv_channels[3] * 2 * 2)  # Use dynamic sizing
        return self.fc1(h4_flattened), self.fc2(h4_flattened)



    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar) # Compute std from logvar
        eps = torch.randn_like(std) # Noise
        return mu + eps * std



    def decode(self, z):
        h3 = F.relu(self.fc3(z))
        h3 = h3.view(-1, self.conv_channels[3], 2, 2)  # Use dynamic sizing
        h4 = F.relu(self.deconv1(h3))
        h5 = F.relu(self.deconv2(h4))
        h6 = F.relu(self.deconv3(h5))
        x_recon = torch.tanh(self.deconv4(h6))
        return x_recon


    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar

def vae_loss(recon_x, x, mu, logvar):
    mse_loss = F.mse_loss(recon_x, x, reduction='sum') # Summing instead of averaging
    kld_loss = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp()) # Kullback-Leibler divergence loss term
    return mse_loss + kld_loss

# %%
def train(model, optimizer, train_loader, device, epoch):
    model.train()  # Set the model to training mode
    train_loss = 0
    for batch_idx, data in enumerate(train_loader):
        data = data.to(device)
        optimizer.zero_grad()
        recon_batch, mu, logvar = model(data)
        loss = vae_loss(recon_batch, data, mu, logvar)
        loss.backward()
        train_loss += loss.item()
        optimizer.step()

    print(f"Epoch {epoch}, Average Train Loss: {train_loss / len(train_loader.dataset):.4f}")

def validate(model, test_loader, device, epoch):
    model.eval()  # Set the model to evaluation mode
    test_loss = 0
    with torch.no_grad():
        for data in test_loader:
            data = data.to(device)
            recon, mu, logvar = model(data)
            test_loss += vae_loss(recon, data, mu, logvar).item()

    test_loss /= len(test_loader.dataset)
    print(f"Epoch {epoch}, Average Test Loss: {test_loss:.4f}")
    return test_loss  # Return the average test loss

# %% [markdown]
# Im going to run the grid search without using batch normalisation and then with and see which one gives me better results after if there is signficant time.

# %%
# Will use 25 epochs for grid search and 100 for final training
num_epochs = 25

# %%
batch_size_options = [32, 64, 128]
conv_channels_options = [[32, 64, 128, 256], [16, 32, 64, 128]]
latent_dim_options = [64, 128, 256]
learning_rate_options = [0,1 ,0.01, 0.001, 0.0001]

# %%
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif self.best_loss - val_loss > self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# Initialize early stopping
early_stopping = EarlyStopping(patience=5, min_delta=0.01)

best_val_loss = float('inf')
best_params = {}
best_time = float('inf')


# Grid Search Loop
for conv_channels, latent_dim, lr, batch_size in itertools.product(conv_channels_options, latent_dim_options, learning_rate_options, batch_size_options):
    # Initialize the model
    model = VAE(conv_channels=conv_channels, latent_dim=latent_dim).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    start_time = time.time()  # Start time measurement

    val_loss = float('inf')  # Initialize to inf to ensure it's always defined

    # Training loop with early stopping
    for epoch in range(1, num_epochs + 1):
        train(model, optimizer, train_loader, device, epoch)
        current_val_loss = validate(model, test_loader, device, epoch)

        if current_val_loss is not None:  # Make sure val_loss is not None
            val_loss = current_val_loss
            early_stopping(val_loss)

            if early_stopping.early_stop:
                print(f"Early stopping triggered at epoch {epoch}!")
                break

    end_time = time.time()  # End time measurement
    training_time = end_time - start_time  # Calculate training time

    # Update the best model if the current model is better
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_params = {
            'conv_channels': conv_channels,
            'latent_dim': latent_dim,
            'lr': lr,
            'batch_size': batch_size
        }
        best_time = training_time

    # Reset early stopping for the next configuration
    early_stopping = EarlyStopping(patience=5, min_delta=0.01)

# After grid search
print(f"Best Validation Loss: {best_val_loss}")
print(f"Best Hyperparameters: {best_params}")
print(f"Training Time for Best Model: {best_time:.2f} seconds")
# Out:
# Epoch 1, Average Train Loss: 603.2490
# Epoch 1, Average Test Loss: 604.2438
# Epoch 2, Average Train Loss: 603.2474
# Epoch 2, Average Test Loss: 604.2517
# Epoch 3, Average Train Loss: 603.2440
# Epoch 3, Average Test Loss: 604.2659
# Epoch 4, Average Train Loss: 603.2456
# Epoch 4, Average Test Loss: 604.2472
# Epoch 5, Average Train Loss: 603.2402
# Epoch 5, Average Test Loss: 604.2676
# Epoch 6, Average Train Loss: 603.2408
# Epoch 6, Average Test Loss: 604.2587
# Early stopping triggered at epoch 6!
# Epoch 1, Average Train Loss: 580.4464
# Epoch 1, Average Test Loss: 581.1524
# Epoch 2, Average Train Loss: 580.4502
# Epoch 2, Average Test Loss: 581.1579
# Epoch 3, Average Train Loss: 580.4492
# Epoch 3, Average Test Loss: 581.1539
# Epoch 4, Average Train Loss: 580.4499
# Epoch 4, Average Test Loss: 581.1541
# Epoch 5, Average Train Loss: 580.4478
# Epoch 5, Average Test Loss: 581.1556
# Epoch 6, Average Train Loss: 580.4478
# Epoch 6, Average Test Loss: 581.1629
# Early stopping triggered at epoch 6!
# Epoch 1, Average Train Loss: 662.1779
# Epoch 1, Average Test Loss: 664.0953
# Epoch 2, Average Train Loss: 662.1841
# Epoch 2, Average Test Loss: 664.1053
# Epoch 3, Average Train Loss: 662.1758
# Epoch 3, Average Test Loss: 664.0750
# Epoch 4, Average Train Loss: 662.1885
# Epoch 4, Average Test Loss: 664.0930
# Epoch 5, Average Train Loss: 662.1737
# Epoch 5, Average Test Loss: 664.1030
# Epoch 6, Average Train Loss: 662.1777
# Epoch 6, Average Test Loss: 664.0936
# Epoch 7, Average Train Loss: 662.1733
# Epoch 7, Average Test Loss: 664.1074
# Epoch 8, Average Train Loss: 662.1767
# Epoch 8, Average Test Loss: 664.1021
# Early stopping triggered at epoch 8!
# Epoch 1, Average Train Loss: nan
# Epoch 1, Average Test Loss: nan
# Epoch 2, Average Train Loss: nan
# Epoch 2, Average Test Loss: nan
# Epoch 3, Average Train Loss: nan
# Epoch 3, Average Test Loss: nan
# Epoch 4, Average Train Loss: nan
# Epoch 4, Average Test Loss: nan
# Epoch 5, Average Train Loss: nan
# Epoch 5, Average Test Loss: nan
# Epoch 6, Average Train Loss: nan
# Epoch 6, Average Test Loss: nan
# Early stopping triggered at epoch 6!
# Epoch 1, Average Train Loss: nan
# Epoch 1, Average Test Loss: nan
# Epoch 2, Average Train Loss: nan
# Epoch 2, Average Test Loss: nan
# Epoch 3, Average Train Loss: nan
# Epoch 3, Average Test Loss: nan
# Epoch 4, Average Train Loss: nan
# Epoch 4, Average Test Loss: nan
# Epoch 5, Average Train Loss: nan
# Epoch 5, Average Test Loss: nan
# Epoch 6, Average Train Loss: nan
# Epoch 6, Average Test Loss: nan
# Early stopping triggered at epoch 6!
# Epoch 1, Average Train Loss: nan
# Epoch 1, Average Test Loss: nan
# Epoch 2, Average Train Loss: nan
# Epoch 2, Average Test Loss: nan
# Epoch 3, Average Train Loss: nan
# Epoch 3, Average Test Loss: nan
# Epoch 4, Average Train Loss: nan
# Epoch 4, Average Test Loss: nan
# Epoch 5, Average Train Loss: nan
# Epoch 5, Average Test Loss: nan
# Epoch 6, Average Train Loss: nan
# Epoch 6, Average Test Loss: nan
# Early stopping triggered at epoch 6!
# Epoch 1, Average Train Loss: 278.8236
# Epoch 1, Average Test Loss: 174.6953
# Epoch 2, Average Train Loss: 178.9029
# Epoch 2, Average Test Loss: 173.4061
# Epoch 3, Average Train Loss: 178.0794
# Epoch 3, Average Test Loss: 172.0172
# Epoch 4, Average Train Loss: 177.5915
# Epoch 4, Average Test Loss: 172.6987
# Epoch 5, Average Train Loss: 177.6462
# Epoch 5, Average Test Loss: 171.8085
# Epoch 6, Average Train Loss: 177.3351
# Epoch 6, Average Test Loss: 171.6054
# Epoch 7, Average Train Loss: 178.1413
# Epoch 7, Average Test Loss: 172.7474
# Epoch 8, Average Train Loss: 177.6654
# Epoch 8, Average Test Loss: 172.1021
# Epoch 9, Average Train Loss: 177.9917
# Epoch 9, Average Test Loss: 172.9304
# Epoch 10, Average Train Loss: 177.0569
# Epoch 10, Average Test Loss: 171.8025
# Epoch 11, Average Train Loss: 177.7308
# Epoch 11, Average Test Loss: 172.1657
# Early stopping triggered at epoch 11!
# Epoch 1, Average Train Loss: 4235251.4443
# Epoch 1, Average Test Loss: 191.6631
# Epoch 2, Average Train Loss: 189.0530
# Epoch 2, Average Test Loss: 179.2368
# Epoch 3, Average Train Loss: 184.1539
# Epoch 3, Average Test Loss: 176.5010
# Epoch 4, Average Train Loss: 181.6821
# Epoch 4, Average Test Loss: 175.6858
# Epoch 5, Average Train Loss: 181.1055
# Epoch 5, Average Test Loss: 175.5664
# Epoch 6, Average Train Loss: 180.6604
# Epoch 6, Average Test Loss: 175.4822
# Epoch 7, Average Train Loss: 179.1586
# Epoch 7, Average Test Loss: 175.6157
# Epoch 8, Average Train Loss: 178.4553
# Epoch 8, Average Test Loss: 172.9141
# Epoch 9, Average Train Loss: 178.5271
# Epoch 9, Average Test Loss: 175.2068
# Epoch 10, Average Train Loss: 178.2693
# Epoch 10, Average Test Loss: 174.2729
# Epoch 11, Average Train Loss: 178.4957
# Epoch 11, Average Test Loss: 172.7514
# Epoch 12, Average Train Loss: 177.9532
# Epoch 12, Average Test Loss: 172.1460
# Epoch 13, Average Train Loss: 177.2172
# Epoch 13, Average Test Loss: 172.5277
# Epoch 14, Average Train Loss: 177.4869
# Epoch 14, Average Test Loss: 172.7140
# Epoch 15, Average Train Loss: 177.5035
# Epoch 15, Average Test Loss: 173.5646
# Epoch 16, Average Train Loss: 177.4832
# Epoch 16, Average Test Loss: 172.2768
# Epoch 17, Average Train Loss: 176.8594
# Epoch 17, Average Test Loss: 171.7898
# Epoch 18, Average Train Loss: 176.9828
# Epoch 18, Average Test Loss: 171.7915
# Epoch 19, Average Train Loss: 177.7565
# Epoch 19, Average Test Loss: 172.7693
# Epoch 20, Average Train Loss: 177.7628
# Epoch 20, Average Test Loss: 171.7452
# Epoch 21, Average Train Loss: 176.9477
# Epoch 21, Average Test Loss: 173.9727
# Epoch 22, Average Train Loss: 177.3112
# Epoch 22, Average Test Loss: 172.2827
# Epoch 23, Average Train Loss: 177.2944
# Epoch 23, Average Test Loss: 172.2273
# Epoch 24, Average Train Loss: 177.7428
# Epoch 24, Average Test Loss: 173.0873
# Epoch 25, Average Train Loss: 177.4020
# Epoch 25, Average Test Loss: 172.6419
# Early stopping triggered at epoch 25!
# Epoch 1, Average Train Loss: 856.7739
# Epoch 1, Average Test Loss: 190.4983
# Epoch 2, Average Train Loss: 188.0177
# Epoch 2, Average Test Loss: 179.9121
# Epoch 3, Average Train Loss: 182.9101
# Epoch 3, Average Test Loss: 175.4872
# Epoch 4, Average Train Loss: 180.3260
# Epoch 4, Average Test Loss: 174.7260
# Epoch 5, Average Train Loss: 179.3343
# Epoch 5, Average Test Loss: 173.9050
# Epoch 6, Average Train Loss: 179.0257
# Epoch 6, Average Test Loss: 173.2889
# Epoch 7, Average Train Loss: 178.3667
# Epoch 7, Average Test Loss: 172.8532
# Epoch 8, Average Train Loss: 178.4513
# Epoch 8, Average Test Loss: 173.4592
# Epoch 9, Average Train Loss: 178.0791
# Epoch 9, Average Test Loss: 173.5223
# Epoch 10, Average Train Loss: 177.5257
# Epoch 10, Average Test Loss: 171.8344
# Epoch 11, Average Train Loss: 177.1946
# Epoch 11, Average Test Loss: 172.1856
# Epoch 12, Average Train Loss: 176.9689
# Epoch 12, Average Test Loss: 171.6601
# Epoch 13, Average Train Loss: 176.9868
# Epoch 13, Average Test Loss: 171.9163
# Epoch 14, Average Train Loss: 176.9551
# Epoch 14, Average Test Loss: 171.8046
# Epoch 15, Average Train Loss: 176.7211
# Epoch 15, Average Test Loss: 171.8046
# Epoch 16, Average Train Loss: 176.9280
# Epoch 16, Average Test Loss: 171.7859
# Epoch 17, Average Train Loss: 176.8877
# Epoch 17, Average Test Loss: 172.0083
# Early stopping triggered at epoch 17!
# Epoch 1, Average Train Loss: 150.1737
# Epoch 1, Average Test Loss: 108.3022
# Epoch 2, Average Train Loss: 100.0507
# Epoch 2, Average Test Loss: 91.7671
# Epoch 3, Average Train Loss: 85.8776
# Epoch 3, Average Test Loss: 81.5786
# Epoch 4, Average Train Loss: 77.1470
# Epoch 4, Average Test Loss: 73.6229
# Epoch 5, Average Train Loss: 71.7256
# Epoch 5, Average Test Loss: 70.0325
# Epoch 6, Average Train Loss: 68.1959
# Epoch 6, Average Test Loss: 67.6914
# Epoch 7, Average Train Loss: 65.7393
# Epoch 7, Average Test Loss: 64.4658
# Epoch 8, Average Train Loss: 63.4146
# Epoch 8, Average Test Loss: 63.2583
# Epoch 9, Average Train Loss: 61.8782
# Epoch 9, Average Test Loss: 63.9041
# Epoch 10, Average Train Loss: 60.2790
# Epoch 10, Average Test Loss: 62.0684
# Epoch 11, Average Train Loss: 59.1609
# Epoch 11, Average Test Loss: 58.9563
# Epoch 12, Average Train Loss: 57.9682
# Epoch 12, Average Test Loss: 58.0817
# Epoch 13, Average Train Loss: 56.8456
# Epoch 13, Average Test Loss: 56.9213
# Epoch 14, Average Train Loss: 55.6315
# Epoch 14, Average Test Loss: 57.7072
# Epoch 15, Average Train Loss: 55.0917
# Epoch 15, Average Test Loss: 56.4595
# Epoch 16, Average Train Loss: 54.4195
# Epoch 16, Average Test Loss: 55.6455
# Epoch 17, Average Train Loss: 53.7133
# Epoch 17, Average Test Loss: 54.3261
# Epoch 18, Average Train Loss: 53.2212
# Epoch 18, Average Test Loss: 55.6627
# Epoch 19, Average Train Loss: 52.8684
# Epoch 19, Average Test Loss: 54.0907
# Epoch 20, Average Train Loss: 52.3449
# Epoch 20, Average Test Loss: 54.1816
# Epoch 21, Average Train Loss: 51.9456
# Epoch 21, Average Test Loss: 53.6124
# Epoch 22, Average Train Loss: 51.4556
# Epoch 22, Average Test Loss: 53.2396
# Epoch 23, Average Train Loss: 50.9782
# Epoch 23, Average Test Loss: 52.8130
# Epoch 24, Average Train Loss: 50.5023
# Epoch 24, Average Test Loss: 53.3483
# Epoch 25, Average Train Loss: 50.4546
# Epoch 25, Average Test Loss: 52.6899
# Epoch 1, Average Train Loss: 215.8832
# Epoch 1, Average Test Loss: 138.0261
# Epoch 2, Average Train Loss: 120.2104
# Epoch 2, Average Test Loss: 109.2564
# Epoch 3, Average Train Loss: 103.5094
# Epoch 3, Average Test Loss: 96.3321
# Epoch 4, Average Train Loss: 91.2221
# Epoch 4, Average Test Loss: 87.2383
# Epoch 5, Average Train Loss: 82.9107
# Epoch 5, Average Test Loss: 79.7333
# Epoch 6, Average Train Loss: 76.6569
# Epoch 6, Average Test Loss: 73.2973
# Epoch 7, Average Train Loss: 71.7936
# Epoch 7, Average Test Loss: 70.6368
# Epoch 8, Average Train Loss: 68.2423
# Epoch 8, Average Test Loss: 67.2745
# Epoch 9, Average Train Loss: 66.2896
# Epoch 9, Average Test Loss: 65.7249
# Epoch 10, Average Train Loss: 64.0641
# Epoch 10, Average Test Loss: 63.8760
# Epoch 11, Average Train Loss: 62.9241
# Epoch 11, Average Test Loss: 62.9181
# Epoch 12, Average Train Loss: 61.1609
# Epoch 12, Average Test Loss: 61.0961
# Epoch 13, Average Train Loss: 60.2365
# Epoch 13, Average Test Loss: 60.8100
# Epoch 14, Average Train Loss: 59.0873
# Epoch 14, Average Test Loss: 60.3159
# Epoch 15, Average Train Loss: 57.9269
# Epoch 15, Average Test Loss: 58.3017
# Epoch 16, Average Train Loss: 57.2613
# Epoch 16, Average Test Loss: 58.2776
# Epoch 17, Average Train Loss: 56.6356
# Epoch 17, Average Test Loss: 56.9699
# Epoch 18, Average Train Loss: 55.9738
# Epoch 18, Average Test Loss: 57.2562
# Epoch 19, Average Train Loss: 55.2199
# Epoch 19, Average Test Loss: 55.7116
# Epoch 20, Average Train Loss: 54.5146
# Epoch 20, Average Test Loss: 56.4767
# Epoch 21, Average Train Loss: 54.0044
# Epoch 21, Average Test Loss: 55.4501
# Epoch 22, Average Train Loss: 53.4351
# Epoch 22, Average Test Loss: 55.0797
# Epoch 23, Average Train Loss: 53.0682
# Epoch 23, Average Test Loss: 53.9076
# Epoch 24, Average Train Loss: 52.5085
# Epoch 24, Average Test Loss: 54.0778
# Epoch 25, Average Train Loss: 52.1537
# Epoch 25, Average Test Loss: 53.7701
# Epoch 1, Average Train Loss: 258.4254
# Epoch 1, Average Test Loss: 154.0773
# Epoch 2, Average Train Loss: 143.1422
# Epoch 2, Average Test Loss: 128.6382
# Epoch 3, Average Train Loss: 118.9888
# Epoch 3, Average Test Loss: 109.9510
# Epoch 4, Average Train Loss: 107.4469
# Epoch 4, Average Test Loss: 102.4486
# Epoch 5, Average Train Loss: 99.7438
# Epoch 5, Average Test Loss: 95.4048
# Epoch 6, Average Train Loss: 91.8288
# Epoch 6, Average Test Loss: 89.0477
# Epoch 7, Average Train Loss: 85.6868
# Epoch 7, Average Test Loss: 82.7875
# Epoch 8, Average Train Loss: 80.4471
# Epoch 8, Average Test Loss: 78.2136
# Epoch 9, Average Train Loss: 76.8602
# Epoch 9, Average Test Loss: 75.2259
# Epoch 10, Average Train Loss: 73.9826
# Epoch 10, Average Test Loss: 73.2700
# Epoch 11, Average Train Loss: 71.5324
# Epoch 11, Average Test Loss: 71.0574
# Epoch 12, Average Train Loss: 69.5452
# Epoch 12, Average Test Loss: 68.3698
# Epoch 13, Average Train Loss: 67.6665
# Epoch 13, Average Test Loss: 67.6265
# Epoch 14, Average Train Loss: 66.0604
# Epoch 14, Average Test Loss: 65.9998
# Epoch 15, Average Train Loss: 64.7473
# Epoch 15, Average Test Loss: 64.6778
# Epoch 16, Average Train Loss: 63.0915
# Epoch 16, Average Test Loss: 63.0395
# Epoch 17, Average Train Loss: 61.9027
# Epoch 17, Average Test Loss: 62.2937
# Epoch 18, Average Train Loss: 61.0252
# Epoch 18, Average Test Loss: 61.0881
# Epoch 19, Average Train Loss: 59.8596
# Epoch 19, Average Test Loss: 60.5960
# Epoch 20, Average Train Loss: 58.9966
# Epoch 20, Average Test Loss: 59.5420
# Epoch 21, Average Train Loss: 58.2631
# Epoch 21, Average Test Loss: 58.8564
# Epoch 22, Average Train Loss: 57.8237
# Epoch 22, Average Test Loss: 58.4816
# Epoch 23, Average Train Loss: 56.6333
# Epoch 23, Average Test Loss: 57.6012
# Epoch 24, Average Train Loss: 56.1092
# Epoch 24, Average Test Loss: 57.1568
# Epoch 25, Average Train Loss: 55.6077
# Epoch 25, Average Test Loss: 57.0923
# Epoch 1, Average Train Loss: 266.4036
# Epoch 1, Average Test Loss: 137.0128
# Epoch 2, Average Train Loss: 124.4478
# Epoch 2, Average Test Loss: 114.8889
# Epoch 3, Average Train Loss: 110.3923
# Epoch 3, Average Test Loss: 106.6358
# Epoch 4, Average Train Loss: 104.0544
# Epoch 4, Average Test Loss: 100.9969
# Epoch 5, Average Train Loss: 98.5960
# Epoch 5, Average Test Loss: 96.7330
# Epoch 6, Average Train Loss: 94.2738
# Epoch 6, Average Test Loss: 92.0392
# Epoch 7, Average Train Loss: 90.4638
# Epoch 7, Average Test Loss: 89.1662
# Epoch 8, Average Train Loss: 87.9062
# Epoch 8, Average Test Loss: 86.9613
# Epoch 9, Average Train Loss: 85.3852
# Epoch 9, Average Test Loss: 84.5620
# Epoch 10, Average Train Loss: 82.9715
# Epoch 10, Average Test Loss: 82.0556
# Epoch 11, Average Train Loss: 80.7971
# Epoch 11, Average Test Loss: 80.2619
# Epoch 12, Average Train Loss: 78.8461
# Epoch 12, Average Test Loss: 78.2678
# Epoch 13, Average Train Loss: 77.0673
# Epoch 13, Average Test Loss: 76.6468
# Epoch 14, Average Train Loss: 75.5607
# Epoch 14, Average Test Loss: 75.9885
# Epoch 15, Average Train Loss: 74.3950
# Epoch 15, Average Test Loss: 74.6648
# Epoch 16, Average Train Loss: 72.7590
# Epoch 16, Average Test Loss: 72.7134
# Epoch 17, Average Train Loss: 71.4873
# Epoch 17, Average Test Loss: 71.4071
# Epoch 18, Average Train Loss: 70.3558
# Epoch 18, Average Test Loss: 71.4879
# Epoch 19, Average Train Loss: 69.1923
# Epoch 19, Average Test Loss: 69.3191
# Epoch 20, Average Train Loss: 68.0676
# Epoch 20, Average Test Loss: 68.0693
# Epoch 21, Average Train Loss: 67.5904
# Epoch 21, Average Test Loss: 67.2493
# Epoch 22, Average Train Loss: 66.8447
# Epoch 22, Average Test Loss: 67.0431
# Epoch 23, Average Train Loss: 65.9929
# Epoch 23, Average Test Loss: 66.4979
# Epoch 24, Average Train Loss: 65.2829
# Epoch 24, Average Test Loss: 65.5351
# Epoch 25, Average Train Loss: 64.5944
# Epoch 25, Average Test Loss: 64.8019
# Epoch 1, Average Train Loss: 283.0660
# Epoch 1, Average Test Loss: 160.0625
# Epoch 2, Average Train Loss: 139.3680
# Epoch 2, Average Test Loss: 123.3371
# Epoch 3, Average Train Loss: 117.0146
# Epoch 3, Average Test Loss: 110.8979
# Epoch 4, Average Train Loss: 108.7295
# Epoch 4, Average Test Loss: 105.2668
# Epoch 5, Average Train Loss: 104.7275
# Epoch 5, Average Test Loss: 102.9268
# Epoch 6, Average Train Loss: 101.4940
# Epoch 6, Average Test Loss: 99.4768
# Epoch 7, Average Train Loss: 98.0813
# Epoch 7, Average Test Loss: 96.2053
# Epoch 8, Average Train Loss: 94.7254
# Epoch 8, Average Test Loss: 93.2159
# Epoch 9, Average Train Loss: 92.1486
# Epoch 9, Average Test Loss: 91.2772
# Epoch 10, Average Train Loss: 89.7035
# Epoch 10, Average Test Loss: 89.1228
# Epoch 11, Average Train Loss: 87.5853
# Epoch 11, Average Test Loss: 87.3501
# Epoch 12, Average Train Loss: 85.7729
# Epoch 12, Average Test Loss: 85.6197
# Epoch 13, Average Train Loss: 83.8158
# Epoch 13, Average Test Loss: 84.4675
# Epoch 14, Average Train Loss: 82.3360
# Epoch 14, Average Test Loss: 81.9941
# Epoch 15, Average Train Loss: 81.0020
# Epoch 15, Average Test Loss: 80.8148
# Epoch 16, Average Train Loss: 79.3907
# Epoch 16, Average Test Loss: 79.3284
# Epoch 17, Average Train Loss: 78.2597
# Epoch 17, Average Test Loss: 77.7803
# Epoch 18, Average Train Loss: 77.0337
# Epoch 18, Average Test Loss: 76.9939
# Epoch 19, Average Train Loss: 75.8621
# Epoch 19, Average Test Loss: 75.8061
# Epoch 20, Average Train Loss: 74.9449
# Epoch 20, Average Test Loss: 74.8882
# Epoch 21, Average Train Loss: 73.8650
# Epoch 21, Average Test Loss: 73.6692
# Epoch 22, Average Train Loss: 72.7920
# Epoch 22, Average Test Loss: 73.0777
# Epoch 23, Average Train Loss: 72.0610
# Epoch 23, Average Test Loss: 71.6931
# Epoch 24, Average Train Loss: 70.8803
# Epoch 24, Average Test Loss: 71.5118
# Epoch 25, Average Train Loss: 70.1797
# Epoch 25, Average Test Loss: 70.6033
# Epoch 1, Average Train Loss: 401.9596
# Epoch 1, Average Test Loss: 228.3920
# Epoch 2, Average Train Loss: 186.9539
# Epoch 2, Average Test Loss: 158.8339
# Epoch 3, Average Train Loss: 146.4510
# Epoch 3, Average Test Loss: 131.2699
# Epoch 4, Average Train Loss: 125.8106
# Epoch 4, Average Test Loss: 119.8045
# Epoch 5, Average Train Loss: 118.4435
# Epoch 5, Average Test Loss: 114.9545
# Epoch 6, Average Train Loss: 113.0298
# Epoch 6, Average Test Loss: 110.1710
# Epoch 7, Average Train Loss: 108.9759
# Epoch 7, Average Test Loss: 107.1423
# Epoch 8, Average Train Loss: 106.0898
# Epoch 8, Average Test Loss: 103.9837
# Epoch 9, Average Train Loss: 103.8912
# Epoch 9, Average Test Loss: 102.6230
# Epoch 10, Average Train Loss: 101.9724
# Epoch 10, Average Test Loss: 100.2228
# Epoch 11, Average Train Loss: 99.4137
# Epoch 11, Average Test Loss: 99.4123
# Epoch 12, Average Train Loss: 97.7582
# Epoch 12, Average Test Loss: 96.9177
# Epoch 13, Average Train Loss: 95.9816
# Epoch 13, Average Test Loss: 95.6934
# Epoch 14, Average Train Loss: 93.6909
# Epoch 14, Average Test Loss: 93.1853
# Epoch 15, Average Train Loss: 92.0591
# Epoch 15, Average Test Loss: 92.0386
# Epoch 16, Average Train Loss: 90.5509
# Epoch 16, Average Test Loss: 90.2419
# Epoch 17, Average Train Loss: 89.2062
# Epoch 17, Average Test Loss: 88.4495
# Epoch 18, Average Train Loss: 87.5262
# Epoch 18, Average Test Loss: 87.8733
# Epoch 19, Average Train Loss: 86.4543
# Epoch 19, Average Test Loss: 86.9670
# Epoch 20, Average Train Loss: 85.3783
# Epoch 20, Average Test Loss: 85.5188
# Epoch 21, Average Train Loss: 84.0704
# Epoch 21, Average Test Loss: 84.2091
# Epoch 22, Average Train Loss: 83.1391
# Epoch 22, Average Test Loss: 83.1566
# Epoch 23, Average Train Loss: 82.1388
# Epoch 23, Average Test Loss: 82.9201
# Epoch 24, Average Train Loss: 81.5640
# Epoch 24, Average Test Loss: 81.4458
# Epoch 25, Average Train Loss: 80.2618
# Epoch 25, Average Test Loss: 80.5953
# Epoch 1, Average Train Loss: 540.6562
# Epoch 1, Average Test Loss: 540.6459
# Epoch 2, Average Train Loss: 540.6514
# Epoch 2, Average Test Loss: 540.6421
# Epoch 3, Average Train Loss: 540.6545
# Epoch 3, Average Test Loss: 540.6370
# Epoch 4, Average Train Loss: 540.6483
# Epoch 4, Average Test Loss: 540.6244
# Epoch 5, Average Train Loss: 540.6505
# Epoch 5, Average Test Loss: 540.6381
# Epoch 6, Average Train Loss: 540.6503
# Epoch 6, Average Test Loss: 540.6300
# Epoch 7, Average Train Loss: 540.6543
# Epoch 7, Average Test Loss: 540.6332
# Epoch 8, Average Train Loss: 540.6565
# Epoch 8, Average Test Loss: 540.6237
# Epoch 9, Average Train Loss: 540.6627
# Epoch 9, Average Test Loss: 540.6225
# Early stopping triggered at epoch 9!
# Epoch 1, Average Train Loss: 797.7081
# Epoch 1, Average Test Loss: 801.3317
# Epoch 2, Average Train Loss: 797.7018
# Epoch 2, Average Test Loss: 801.3396
# Epoch 3, Average Train Loss: 797.6969
# Epoch 3, Average Test Loss: 801.3200
# Epoch 4, Average Train Loss: 797.6990
# Epoch 4, Average Test Loss: 801.3362
# Epoch 5, Average Train Loss: 797.6997
# Epoch 5, Average Test Loss: 801.3138
# Epoch 6, Average Train Loss: 797.6976
# Epoch 6, Average Test Loss: 801.3294
# Epoch 7, Average Train Loss: 797.6993
# Epoch 7, Average Test Loss: 801.3313
# Epoch 8, Average Train Loss: 797.6934
# Epoch 8, Average Test Loss: 801.3149
# Early stopping triggered at epoch 8!
# Epoch 1, Average Train Loss: 805.4946
# Epoch 1, Average Test Loss: 809.1211
# Epoch 2, Average Train Loss: 805.5048
# Epoch 2, Average Test Loss: 809.1254
# Epoch 3, Average Train Loss: 805.4918
# Epoch 3, Average Test Loss: 809.1421
# Epoch 4, Average Train Loss: 805.4910
# Epoch 4, Average Test Loss: 809.1223
# Epoch 5, Average Train Loss: 805.4929
# Epoch 5, Average Test Loss: 809.1151
# Epoch 6, Average Train Loss: 805.4983
# Epoch 6, Average Test Loss: 809.1228
# Early stopping triggered at epoch 6!
# Epoch 1, Average Train Loss: nan
# Epoch 1, Average Test Loss: nan
# Epoch 2, Average Train Loss: nan
# Epoch 2, Average Test Loss: nan
# Epoch 3, Average Train Loss: nan
# Epoch 3, Average Test Loss: nan
# Epoch 4, Average Train Loss: nan
# Epoch 4, Average Test Loss: nan
# Epoch 5, Average Train Loss: nan
# Epoch 5, Average Test Loss: nan
# Epoch 6, Average Train Loss: nan
# Epoch 6, Average Test Loss: nan
# Early stopping triggered at epoch 6!
# Epoch 1, Average Train Loss: nan
# Epoch 1, Average Test Loss: nan
# Epoch 2, Average Train Loss: nan
# Epoch 2, Average Test Loss: nan
# Epoch 3, Average Train Loss: nan
# Epoch 3, Average Test Loss: nan
# Epoch 4, Average Train Loss: nan
# Epoch 4, Average Test Loss: nan
# Epoch 5, Average Train Loss: nan
# Epoch 5, Average Test Loss: nan
# Epoch 6, Average Train Loss: nan
# Epoch 6, Average Test Loss: nan
# Early stopping triggered at epoch 6!
# Epoch 1, Average Train Loss: nan
# Epoch 1, Average Test Loss: nan
# Epoch 2, Average Train Loss: nan
# Epoch 2, Average Test Loss: nan
# Epoch 3, Average Train Loss: nan
# Epoch 3, Average Test Loss: nan
# Epoch 4, Average Train Loss: nan
# Epoch 4, Average Test Loss: nan
# Epoch 5, Average Train Loss: nan
# Epoch 5, Average Test Loss: nan
# Epoch 6, Average Train Loss: nan
# Epoch 6, Average Test Loss: nan
# Early stopping triggered at epoch 6!
# Epoch 1, Average Train Loss: 235.9347
# Epoch 1, Average Test Loss: 190.8424
# Epoch 2, Average Train Loss: 191.1257
# Epoch 2, Average Test Loss: 182.3905
# Epoch 3, Average Train Loss: 182.1268
# Epoch 3, Average Test Loss: 173.2966
# Epoch 4, Average Train Loss: 179.8037
# Epoch 4, Average Test Loss: 173.6824
# Epoch 5, Average Train Loss: 180.1486
# Epoch 5, Average Test Loss: 172.6940
# Epoch 6, Average Train Loss: 178.1287
# Epoch 6, Average Test Loss: 173.7308
# Epoch 7, Average Train Loss: 178.1742
# Epoch 7, Average Test Loss: 173.3778
# Epoch 8, Average Train Loss: 178.2198
# Epoch 8, Average Test Loss: 173.2786
# Epoch 9, Average Train Loss: 178.1603
# Epoch 9, Average Test Loss: 173.6449
# Epoch 10, Average Train Loss: 177.4851
# Epoch 10, Average Test Loss: 172.9981
# Early stopping triggered at epoch 10!
# Epoch 1, Average Train Loss: 308.7971
# Epoch 1, Average Test Loss: 173.6552
# Epoch 2, Average Train Loss: 178.0009
# Epoch 2, Average Test Loss: 172.6866
# Epoch 3, Average Train Loss: 178.0686
# Epoch 3, Average Test Loss: 173.4929
# Epoch 4, Average Train Loss: 177.6103
# Epoch 4, Average Test Loss: 172.4392
# Epoch 5, Average Train Loss: 177.0867
# Epoch 5, Average Test Loss: 171.6446
# Epoch 6, Average Train Loss: 177.9312
# Epoch 6, Average Test Loss: 173.5743
# Epoch 7, Average Train Loss: 176.9732
# Epoch 7, Average Test Loss: 172.5395
# Epoch 8, Average Train Loss: 177.0168
# Epoch 8, Average Test Loss: 171.1571
# Epoch 9, Average Train Loss: 176.6151
# Epoch 9, Average Test Loss: 171.4182
# Epoch 10, Average Train Loss: 176.4766
# Epoch 10, Average Test Loss: 171.9889
# Epoch 11, Average Train Loss: 177.0397
# Epoch 11, Average Test Loss: 171.9018
# Epoch 12, Average Train Loss: 176.8132
# Epoch 12, Average Test Loss: 171.5926
# Epoch 13, Average Train Loss: 176.8070
# Epoch 13, Average Test Loss: 171.4784
# Early stopping triggered at epoch 13!
# Epoch 1, Average Train Loss: 393.9080
# Epoch 1, Average Test Loss: 204.2167
# Epoch 2, Average Train Loss: 199.9440
# Epoch 2, Average Test Loss: 183.4790
# Epoch 3, Average Train Loss: 187.5037
# Epoch 3, Average Test Loss: 183.8244
# Epoch 4, Average Train Loss: 181.6910
# Epoch 4, Average Test Loss: 176.5052
# Epoch 5, Average Train Loss: 179.5415
# Epoch 5, Average Test Loss: 173.2157
# Epoch 6, Average Train Loss: 179.6581
# Epoch 6, Average Test Loss: 174.0591
# Epoch 7, Average Train Loss: 178.0883
# Epoch 7, Average Test Loss: 172.1416
# Epoch 8, Average Train Loss: 177.9357
# Epoch 8, Average Test Loss: 172.7737
# Epoch 9, Average Train Loss: 177.7878
# Epoch 9, Average Test Loss: 172.4472
# Epoch 10, Average Train Loss: 177.3470
# Epoch 10, Average Test Loss: 171.5781
# Epoch 11, Average Train Loss: 177.0512
# Epoch 11, Average Test Loss: 171.4294
# Epoch 12, Average Train Loss: 176.8626
# Epoch 12, Average Test Loss: 173.3631
# Epoch 13, Average Train Loss: 177.6184
# Epoch 13, Average Test Loss: 172.2790
# Epoch 14, Average Train Loss: 176.6066
# Epoch 14, Average Test Loss: 172.7523
# Epoch 15, Average Train Loss: 176.8179
# Epoch 15, Average Test Loss: 172.4189
# Epoch 16, Average Train Loss: 176.4104
# Epoch 16, Average Test Loss: 171.9795
# Early stopping triggered at epoch 16!
# Epoch 1, Average Train Loss: 154.9291
# Epoch 1, Average Test Loss: 113.2504
# Epoch 2, Average Train Loss: 104.4022
# Epoch 2, Average Test Loss: 96.2688
# Epoch 3, Average Train Loss: 91.7431
# Epoch 3, Average Test Loss: 86.5451
# Epoch 4, Average Train Loss: 84.1621
# Epoch 4, Average Test Loss: 82.4622
# Epoch 5, Average Train Loss: 77.9884
# Epoch 5, Average Test Loss: 76.9108
# Epoch 6, Average Train Loss: 73.8813
# Epoch 6, Average Test Loss: 73.4230
# Epoch 7, Average Train Loss: 70.4088
# Epoch 7, Average Test Loss: 68.9249
# Epoch 8, Average Train Loss: 66.4149
# Epoch 8, Average Test Loss: 66.4995
# Epoch 9, Average Train Loss: 64.5609
# Epoch 9, Average Test Loss: 63.2726
# Epoch 10, Average Train Loss: 62.4409
# Epoch 10, Average Test Loss: 62.8165
# Epoch 11, Average Train Loss: 61.1672
# Epoch 11, Average Test Loss: 62.3255
# Epoch 12, Average Train Loss: 60.0904
# Epoch 12, Average Test Loss: 60.5029
# Epoch 13, Average Train Loss: 59.1920
# Epoch 13, Average Test Loss: 59.0505
# Epoch 14, Average Train Loss: 58.2216
# Epoch 14, Average Test Loss: 58.9485
# Epoch 15, Average Train Loss: 57.2421
# Epoch 15, Average Test Loss: 58.5626
# Epoch 16, Average Train Loss: 56.7859
# Epoch 16, Average Test Loss: 57.1114
# Epoch 17, Average Train Loss: 56.0292
# Epoch 17, Average Test Loss: 56.6176
# Epoch 18, Average Train Loss: 55.4462
# Epoch 18, Average Test Loss: 56.3522
# Epoch 19, Average Train Loss: 55.0318
# Epoch 19, Average Test Loss: 57.5488
# Epoch 20, Average Train Loss: 54.5355
# Epoch 20, Average Test Loss: 55.8792
# Epoch 21, Average Train Loss: 54.0007
# Epoch 21, Average Test Loss: 55.2096
# Epoch 22, Average Train Loss: 53.9016
# Epoch 22, Average Test Loss: 55.2974
# Epoch 23, Average Train Loss: 52.8897
# Epoch 23, Average Test Loss: 54.7289
# Epoch 24, Average Train Loss: 52.7568
# Epoch 24, Average Test Loss: 54.1382
# Epoch 25, Average Train Loss: 52.5095
# Epoch 25, Average Test Loss: 54.9601
# Epoch 1, Average Train Loss: 211.3882
# Epoch 1, Average Test Loss: 135.1929
# Epoch 2, Average Train Loss: 118.9438
# Epoch 2, Average Test Loss: 108.4838
# Epoch 3, Average Train Loss: 105.9542
# Epoch 3, Average Test Loss: 101.3147
# Epoch 4, Average Train Loss: 97.6375
# Epoch 4, Average Test Loss: 95.1272
# Epoch 5, Average Train Loss: 91.0744
# Epoch 5, Average Test Loss: 88.0768
# Epoch 6, Average Train Loss: 85.1718
# Epoch 6, Average Test Loss: 81.7039
# Epoch 7, Average Train Loss: 79.6472
# Epoch 7, Average Test Loss: 76.2889
# Epoch 8, Average Train Loss: 74.4326
# Epoch 8, Average Test Loss: 72.5609
# Epoch 9, Average Train Loss: 70.4732
# Epoch 9, Average Test Loss: 69.2298
# Epoch 10, Average Train Loss: 67.8035
# Epoch 10, Average Test Loss: 67.0482
# Epoch 11, Average Train Loss: 65.4813
# Epoch 11, Average Test Loss: 65.5563
# Epoch 12, Average Train Loss: 63.7210
# Epoch 12, Average Test Loss: 63.2388
# Epoch 13, Average Train Loss: 62.1563
# Epoch 13, Average Test Loss: 61.8607
# Epoch 14, Average Train Loss: 60.7658
# Epoch 14, Average Test Loss: 61.7154
# Epoch 15, Average Train Loss: 60.0866
# Epoch 15, Average Test Loss: 60.2890
# Epoch 16, Average Train Loss: 59.1191
# Epoch 16, Average Test Loss: 59.5020
# Epoch 17, Average Train Loss: 58.3103
# Epoch 17, Average Test Loss: 59.4588
# Epoch 18, Average Train Loss: 57.8047
# Epoch 18, Average Test Loss: 59.0792
# Epoch 19, Average Train Loss: 57.1235
# Epoch 19, Average Test Loss: 58.5119
# Epoch 20, Average Train Loss: 56.0984
# Epoch 20, Average Test Loss: 57.9615
# Epoch 21, Average Train Loss: 56.0178
# Epoch 21, Average Test Loss: 57.3004
# Epoch 22, Average Train Loss: 55.6518
# Epoch 22, Average Test Loss: 56.5563
# Epoch 23, Average Train Loss: 55.0555
# Epoch 23, Average Test Loss: 56.8584
# Epoch 24, Average Train Loss: 54.6945
# Epoch 24, Average Test Loss: 56.7073
# Epoch 25, Average Train Loss: 54.3711
# Epoch 25, Average Test Loss: 55.6542
# Epoch 1, Average Train Loss: 276.4059
# Epoch 1, Average Test Loss: 152.6078
# Epoch 2, Average Train Loss: 146.0575
# Epoch 2, Average Test Loss: 131.1467
# Epoch 3, Average Train Loss: 121.6904
# Epoch 3, Average Test Loss: 114.5669
# Epoch 4, Average Train Loss: 110.5139
# Epoch 4, Average Test Loss: 106.8021
# Epoch 5, Average Train Loss: 103.1586
# Epoch 5, Average Test Loss: 99.8737
# Epoch 6, Average Train Loss: 98.4146
# Epoch 6, Average Test Loss: 94.9689
# Epoch 7, Average Train Loss: 92.8339
# Epoch 7, Average Test Loss: 90.3538
# Epoch 8, Average Train Loss: 88.8259
# Epoch 8, Average Test Loss: 86.2351
# Epoch 9, Average Train Loss: 84.1009
# Epoch 9, Average Test Loss: 82.1397
# Epoch 10, Average Train Loss: 80.4984
# Epoch 10, Average Test Loss: 79.2952
# Epoch 11, Average Train Loss: 77.2197
# Epoch 11, Average Test Loss: 76.4755
# Epoch 12, Average Train Loss: 74.6002
# Epoch 12, Average Test Loss: 74.7849
# Epoch 13, Average Train Loss: 72.3878
# Epoch 13, Average Test Loss: 71.5530
# Epoch 14, Average Train Loss: 70.3599
# Epoch 14, Average Test Loss: 69.4529
# Epoch 15, Average Train Loss: 68.5547
# Epoch 15, Average Test Loss: 68.0168
# Epoch 16, Average Train Loss: 67.0520
# Epoch 16, Average Test Loss: 66.3593
# Epoch 17, Average Train Loss: 65.8149
# Epoch 17, Average Test Loss: 67.0661
# Epoch 18, Average Train Loss: 64.5981
# Epoch 18, Average Test Loss: 64.0517
# Epoch 19, Average Train Loss: 63.0936
# Epoch 19, Average Test Loss: 63.3854
# Epoch 20, Average Train Loss: 62.1899
# Epoch 20, Average Test Loss: 62.6663
# Epoch 21, Average Train Loss: 61.5375
# Epoch 21, Average Test Loss: 62.6417
# Epoch 22, Average Train Loss: 60.6100
# Epoch 22, Average Test Loss: 61.0376
# Epoch 23, Average Train Loss: 59.8420
# Epoch 23, Average Test Loss: 60.4900
# Epoch 24, Average Train Loss: 58.7398
# Epoch 24, Average Test Loss: 59.9860
# Epoch 25, Average Train Loss: 58.3919
# Epoch 25, Average Test Loss: 58.6032
# Epoch 1, Average Train Loss: 215.5675
# Epoch 1, Average Test Loss: 125.3430
# Epoch 2, Average Train Loss: 118.2647
# Epoch 2, Average Test Loss: 111.6000
# Epoch 3, Average Train Loss: 109.8316
# Epoch 3, Average Test Loss: 105.6823
# Epoch 4, Average Train Loss: 105.0995
# Epoch 4, Average Test Loss: 105.4778
# Epoch 5, Average Train Loss: 101.8219
# Epoch 5, Average Test Loss: 100.2052
# Epoch 6, Average Train Loss: 98.4109
# Epoch 6, Average Test Loss: 97.1375
# Epoch 7, Average Train Loss: 96.0234
# Epoch 7, Average Test Loss: 96.1619
# Epoch 8, Average Train Loss: 94.0190
# Epoch 8, Average Test Loss: 92.8370
# Epoch 9, Average Train Loss: 91.5748
# Epoch 9, Average Test Loss: 92.0843
# Epoch 10, Average Train Loss: 89.6495
# Epoch 10, Average Test Loss: 89.5520
# Epoch 11, Average Train Loss: 87.5737
# Epoch 11, Average Test Loss: 88.3050
# Epoch 12, Average Train Loss: 85.6216
# Epoch 12, Average Test Loss: 85.2419
# Epoch 13, Average Train Loss: 83.4914
# Epoch 13, Average Test Loss: 82.6952
# Epoch 14, Average Train Loss: 81.7145
# Epoch 14, Average Test Loss: 81.1135
# Epoch 15, Average Train Loss: 79.8475
# Epoch 15, Average Test Loss: 80.0752
# Epoch 16, Average Train Loss: 78.1339
# Epoch 16, Average Test Loss: 78.3594
# Epoch 17, Average Train Loss: 76.9929
# Epoch 17, Average Test Loss: 76.6358
# Epoch 18, Average Train Loss: 75.6335
# Epoch 18, Average Test Loss: 74.8566
# Epoch 19, Average Train Loss: 73.8917
# Epoch 19, Average Test Loss: 73.9032
# Epoch 20, Average Train Loss: 72.9713
# Epoch 20, Average Test Loss: 73.0139
# Epoch 21, Average Train Loss: 71.8219
# Epoch 21, Average Test Loss: 72.2047
# Epoch 22, Average Train Loss: 70.7412
# Epoch 22, Average Test Loss: 70.5009
# Epoch 23, Average Train Loss: 70.0063
# Epoch 23, Average Test Loss: 70.6397
# Epoch 24, Average Train Loss: 69.1981
# Epoch 24, Average Test Loss: 69.6370
# Epoch 25, Average Train Loss: 68.3370
# Epoch 25, Average Test Loss: 68.6164
# Epoch 1, Average Train Loss: 366.6092
# Epoch 1, Average Test Loss: 169.5568
# Epoch 2, Average Train Loss: 150.8138
# Epoch 2, Average Test Loss: 130.1517
# Epoch 3, Average Train Loss: 125.0994
# Epoch 3, Average Test Loss: 120.3548
# Epoch 4, Average Train Loss: 116.3044
# Epoch 4, Average Test Loss: 112.1725
# Epoch 5, Average Train Loss: 110.8669
# Epoch 5, Average Test Loss: 107.6942
# Epoch 6, Average Train Loss: 107.4022
# Epoch 6, Average Test Loss: 105.4457
# Epoch 7, Average Train Loss: 104.6679
# Epoch 7, Average Test Loss: 102.7240
# Epoch 8, Average Train Loss: 102.2953
# Epoch 8, Average Test Loss: 100.2529
# Epoch 9, Average Train Loss: 99.8584
# Epoch 9, Average Test Loss: 98.3171
# Epoch 10, Average Train Loss: 97.5041
# Epoch 10, Average Test Loss: 96.9340
# Epoch 11, Average Train Loss: 95.6091
# Epoch 11, Average Test Loss: 95.8178
# Epoch 12, Average Train Loss: 93.6089
# Epoch 12, Average Test Loss: 93.5890
# Epoch 13, Average Train Loss: 91.8509
# Epoch 13, Average Test Loss: 90.9212
# Epoch 14, Average Train Loss: 90.1563
# Epoch 14, Average Test Loss: 89.9255
# Epoch 15, Average Train Loss: 88.4156
# Epoch 15, Average Test Loss: 88.5276
# Epoch 16, Average Train Loss: 86.8272
# Epoch 16, Average Test Loss: 86.4454
# Epoch 17, Average Train Loss: 85.4208
# Epoch 17, Average Test Loss: 84.5812
# Epoch 18, Average Train Loss: 84.0043
# Epoch 18, Average Test Loss: 83.3301
# Epoch 19, Average Train Loss: 82.6600
# Epoch 19, Average Test Loss: 82.1101
# Epoch 20, Average Train Loss: 81.3995
# Epoch 20, Average Test Loss: 81.3933
# Epoch 21, Average Train Loss: 80.2962
# Epoch 21, Average Test Loss: 80.3907
# Epoch 22, Average Train Loss: 79.3851
# Epoch 22, Average Test Loss: 79.3532
# Epoch 23, Average Train Loss: 78.4547
# Epoch 23, Average Test Loss: 78.9694
# Epoch 24, Average Train Loss: 77.9961
# Epoch 24, Average Test Loss: 78.4083
# Epoch 25, Average Train Loss: 77.1219
# Epoch 25, Average Test Loss: 77.2093
# Epoch 1, Average Train Loss: 425.9807
# Epoch 1, Average Test Loss: 262.5839
# Epoch 2, Average Train Loss: 197.2346
# Epoch 2, Average Test Loss: 162.6870
# Epoch 3, Average Train Loss: 154.1888
# Epoch 3, Average Test Loss: 135.9395
# Epoch 4, Average Train Loss: 129.5653
# Epoch 4, Average Test Loss: 123.6036
# Epoch 5, Average Train Loss: 120.8613
# Epoch 5, Average Test Loss: 118.8665
# Epoch 6, Average Train Loss: 115.6184
# Epoch 6, Average Test Loss: 112.8126
# Epoch 7, Average Train Loss: 111.7459
# Epoch 7, Average Test Loss: 109.1120
# Epoch 8, Average Train Loss: 109.0348
# Epoch 8, Average Test Loss: 107.8054
# Epoch 9, Average Train Loss: 106.8680
# Epoch 9, Average Test Loss: 106.3162
# Epoch 10, Average Train Loss: 105.2763
# Epoch 10, Average Test Loss: 105.2032
# Epoch 11, Average Train Loss: 104.2380
# Epoch 11, Average Test Loss: 102.7842
# Epoch 12, Average Train Loss: 102.4899
# Epoch 12, Average Test Loss: 101.8932
# Epoch 13, Average Train Loss: 101.3323
# Epoch 13, Average Test Loss: 100.1226
# Epoch 14, Average Train Loss: 100.1029
# Epoch 14, Average Test Loss: 99.5214
# Epoch 15, Average Train Loss: 98.4365
# Epoch 15, Average Test Loss: 98.6882
# Epoch 16, Average Train Loss: 97.3065
# Epoch 16, Average Test Loss: 95.6800
# Epoch 17, Average Train Loss: 95.5048
# Epoch 17, Average Test Loss: 95.5401
# Epoch 18, Average Train Loss: 94.5529
# Epoch 18, Average Test Loss: 93.3456
# Epoch 19, Average Train Loss: 92.8644
# Epoch 19, Average Test Loss: 93.3206
# Epoch 20, Average Train Loss: 92.1181
# Epoch 20, Average Test Loss: 91.1430
# Epoch 21, Average Train Loss: 90.9732
# Epoch 21, Average Test Loss: 90.8179
# Epoch 22, Average Train Loss: 89.8684
# Epoch 22, Average Test Loss: 89.6140
# Epoch 23, Average Train Loss: 89.1184
# Epoch 23, Average Test Loss: 89.0344
# Epoch 24, Average Train Loss: 88.0690
# Epoch 24, Average Test Loss: 87.9784
# Epoch 25, Average Train Loss: 87.1708
# Epoch 25, Average Test Loss: 87.0841
# Epoch 1, Average Train Loss: 622.1599
# Epoch 1, Average Test Loss: 623.5105
# Epoch 2, Average Train Loss: 622.1608
# Epoch 2, Average Test Loss: 623.5010
# Epoch 3, Average Train Loss: 622.1625
# Epoch 3, Average Test Loss: 623.5107
# Epoch 4, Average Train Loss: 622.1613
# Epoch 4, Average Test Loss: 623.5038
# Epoch 5, Average Train Loss: 622.1607
# Epoch 5, Average Test Loss: 623.5098
# Epoch 6, Average Train Loss: 622.1572
# Epoch 6, Average Test Loss: 623.4956
# Epoch 7, Average Train Loss: 622.1567
# Epoch 7, Average Test Loss: 623.5118
# Epoch 8, Average Train Loss: 622.1630
# Epoch 8, Average Test Loss: 623.4993
# Epoch 9, Average Train Loss: 622.1577
# Epoch 9, Average Test Loss: 623.5046
# Epoch 10, Average Train Loss: 622.1614
# Epoch 10, Average Test Loss: 623.5094
# Epoch 11, Average Train Loss: 622.1558
# Epoch 11, Average Test Loss: 623.5186
# Early stopping triggered at epoch 11!
# Epoch 1, Average Train Loss: 441.2963
# Epoch 1, Average Test Loss: 438.8185
# Epoch 2, Average Train Loss: 441.2958
# Epoch 2, Average Test Loss: 438.8160
# Epoch 3, Average Train Loss: 441.2952
# Epoch 3, Average Test Loss: 438.8138
# Epoch 4, Average Train Loss: 441.2991
# Epoch 4, Average Test Loss: 438.8129
# Epoch 5, Average Train Loss: 441.3007
# Epoch 5, Average Test Loss: 438.8245
# Epoch 6, Average Train Loss: 441.2980
# Epoch 6, Average Test Loss: 438.8099
# Early stopping triggered at epoch 6!
# Epoch 1, Average Train Loss: 662.5076
# Epoch 1, Average Test Loss: 664.2709
# Epoch 2, Average Train Loss: 662.5065
# Epoch 2, Average Test Loss: 664.2730
# Epoch 3, Average Train Loss: 662.5062
# Epoch 3, Average Test Loss: 664.2828
# Epoch 4, Average Train Loss: 662.4993
# Epoch 4, Average Test Loss: 664.2902
# Epoch 5, Average Train Loss: 662.5027
# Epoch 5, Average Test Loss: 664.2855
# Epoch 6, Average Train Loss: 662.5086
# Epoch 6, Average Test Loss: 664.2656
# Early stopping triggered at epoch 6!
# Epoch 1, Average Train Loss: nan
# Epoch 1, Average Test Loss: nan
# Epoch 2, Average Train Loss: nan
# Epoch 2, Average Test Loss: nan
# Epoch 3, Average Train Loss: nan
# Epoch 3, Average Test Loss: nan
# Epoch 4, Average Train Loss: nan
# Epoch 4, Average Test Loss: nan
# Epoch 5, Average Train Loss: nan
# Epoch 5, Average Test Loss: nan
# Epoch 6, Average Train Loss: nan
# Epoch 6, Average Test Loss: nan
# Early stopping triggered at epoch 6!
# Epoch 1, Average Train Loss: nan
# Epoch 1, Average Test Loss: nan
# Epoch 2, Average Train Loss: nan
# Epoch 2, Average Test Loss: nan
# Epoch 3, Average Train Loss: nan
# Epoch 3, Average Test Loss: nan
# Epoch 4, Average Train Loss: nan
# Epoch 4, Average Test Loss: nan
# Epoch 5, Average Train Loss: nan
# Epoch 5, Average Test Loss: nan
# Epoch 6, Average Train Loss: nan
# Epoch 6, Average Test Loss: nan
# Early stopping triggered at epoch 6!
# Epoch 1, Average Train Loss: nan
# Epoch 1, Average Test Loss: nan
# Epoch 2, Average Train Loss: nan
# Epoch 2, Average Test Loss: nan
# Epoch 3, Average Train Loss: nan
# Epoch 3, Average Test Loss: nan
# Epoch 4, Average Train Loss: nan
# Epoch 4, Average Test Loss: nan
# Epoch 5, Average Train Loss: nan
# Epoch 5, Average Test Loss: nan
# Epoch 6, Average Train Loss: nan
# Epoch 6, Average Test Loss: nan
# Early stopping triggered at epoch 6!
# Epoch 1, Average Train Loss: 254.8904
# Epoch 1, Average Test Loss: 180.1526
# Epoch 2, Average Train Loss: 181.3817
# Epoch 2, Average Test Loss: 178.7924
# Epoch 3, Average Train Loss: 179.3645
# Epoch 3, Average Test Loss: 172.7192
# Epoch 4, Average Train Loss: 179.3246
# Epoch 4, Average Test Loss: 174.3643
# Epoch 5, Average Train Loss: 179.0528
# Epoch 5, Average Test Loss: 172.4001
# Epoch 6, Average Train Loss: 179.2192
# Epoch 6, Average Test Loss: 178.5826
# Epoch 7, Average Train Loss: 181.3926
# Epoch 7, Average Test Loss: 176.0258
# Epoch 8, Average Train Loss: 181.1344
# Epoch 8, Average Test Loss: 175.4505
# Epoch 9, Average Train Loss: 181.0543
# Epoch 9, Average Test Loss: 175.0895
# Epoch 10, Average Train Loss: 180.2355
# Epoch 10, Average Test Loss: 174.8785
# Early stopping triggered at epoch 10!
# Epoch 1, Average Train Loss: 351.6178
# Epoch 1, Average Test Loss: 180.9585
# Epoch 2, Average Train Loss: 182.9852
# Epoch 2, Average Test Loss: 176.3299
# Epoch 3, Average Train Loss: 180.5646
# Epoch 3, Average Test Loss: 176.4060
# Epoch 4, Average Train Loss: 179.2961
# Epoch 4, Average Test Loss: 173.4006
# Epoch 5, Average Train Loss: 178.7241
# Epoch 5, Average Test Loss: 172.1074
# Epoch 6, Average Train Loss: 177.8902
# Epoch 6, Average Test Loss: 172.3746
# Epoch 7, Average Train Loss: 178.2187
# Epoch 7, Average Test Loss: 174.2139
# Epoch 8, Average Train Loss: 179.1414
# Epoch 8, Average Test Loss: 173.1261
# Epoch 9, Average Train Loss: 177.5892
# Epoch 9, Average Test Loss: 172.0242
# Epoch 10, Average Train Loss: 177.3287
# Epoch 10, Average Test Loss: 171.4669
# Epoch 11, Average Train Loss: 177.3978
# Epoch 11, Average Test Loss: 171.9286
# Epoch 12, Average Train Loss: 177.1325
# Epoch 12, Average Test Loss: 171.6101
# Epoch 13, Average Train Loss: 179.0366
# Epoch 13, Average Test Loss: 174.4399
# Epoch 14, Average Train Loss: 179.4270
# Epoch 14, Average Test Loss: 171.9640
# Epoch 15, Average Train Loss: 180.1437
# Epoch 15, Average Test Loss: 175.6465
# Early stopping triggered at epoch 15!
# Epoch 1, Average Train Loss: 346.7080
# Epoch 1, Average Test Loss: 185.9584
# Epoch 2, Average Train Loss: 183.7680
# Epoch 2, Average Test Loss: 179.3070
# Epoch 3, Average Train Loss: 179.5358
# Epoch 3, Average Test Loss: 172.8773
# Epoch 4, Average Train Loss: 177.9027
# Epoch 4, Average Test Loss: 172.0742
# Epoch 5, Average Train Loss: 177.7900
# Epoch 5, Average Test Loss: 172.0373
# Epoch 6, Average Train Loss: 178.8768
# Epoch 6, Average Test Loss: 172.5455
# Epoch 7, Average Train Loss: 177.1968
# Epoch 7, Average Test Loss: 172.0080
# Epoch 8, Average Train Loss: 176.6363
# Epoch 8, Average Test Loss: 171.9587
# Epoch 9, Average Train Loss: 176.8945
# Epoch 9, Average Test Loss: 171.6482
# Epoch 10, Average Train Loss: 176.7360
# Epoch 10, Average Test Loss: 171.9656
# Epoch 11, Average Train Loss: 176.9801
# Epoch 11, Average Test Loss: 172.1643
# Epoch 12, Average Train Loss: 176.8565
# Epoch 12, Average Test Loss: 171.9380
# Epoch 13, Average Train Loss: 176.7839
# Epoch 13, Average Test Loss: 171.8109
# Epoch 14, Average Train Loss: 176.8582
# Epoch 14, Average Test Loss: 171.8424
# Early stopping triggered at epoch 14!
# Epoch 1, Average Train Loss: 165.8414
# Epoch 1, Average Test Loss: 119.2166
# Epoch 2, Average Train Loss: 109.3070
# Epoch 2, Average Test Loss: 101.6794
# Epoch 3, Average Train Loss: 99.3850
# Epoch 3, Average Test Loss: 95.9377
# Epoch 4, Average Train Loss: 92.6885
# Epoch 4, Average Test Loss: 90.1793
# Epoch 5, Average Train Loss: 88.5806
# Epoch 5, Average Test Loss: 87.0654
# Epoch 6, Average Train Loss: 84.5262
# Epoch 6, Average Test Loss: 82.8661
# Epoch 7, Average Train Loss: 81.0460
# Epoch 7, Average Test Loss: 80.3735
# Epoch 8, Average Train Loss: 78.8409
# Epoch 8, Average Test Loss: 77.5447
# Epoch 9, Average Train Loss: 74.9178
# Epoch 9, Average Test Loss: 74.1037
# Epoch 10, Average Train Loss: 72.8127
# Epoch 10, Average Test Loss: 72.6566
# Epoch 11, Average Train Loss: 70.0548
# Epoch 11, Average Test Loss: 69.5070
# Epoch 12, Average Train Loss: 68.0255
# Epoch 12, Average Test Loss: 68.7621
# Epoch 13, Average Train Loss: 66.6615
# Epoch 13, Average Test Loss: 67.0308
# Epoch 14, Average Train Loss: 65.0478
# Epoch 14, Average Test Loss: 64.8207
# Epoch 15, Average Train Loss: 63.3249
# Epoch 15, Average Test Loss: 63.9947
# Epoch 16, Average Train Loss: 62.2437
# Epoch 16, Average Test Loss: 63.3470
# Epoch 17, Average Train Loss: 61.2231
# Epoch 17, Average Test Loss: 62.2727
# Epoch 18, Average Train Loss: 60.6004
# Epoch 18, Average Test Loss: 60.5616
# Epoch 19, Average Train Loss: 59.8390
# Epoch 19, Average Test Loss: 60.6186
# Epoch 20, Average Train Loss: 59.1467
# Epoch 20, Average Test Loss: 60.0699
# Epoch 21, Average Train Loss: 58.4471
# Epoch 21, Average Test Loss: 59.1121
# Epoch 22, Average Train Loss: 57.9223
# Epoch 22, Average Test Loss: 59.2253
# Epoch 23, Average Train Loss: 57.1424
# Epoch 23, Average Test Loss: 58.4047
# Epoch 24, Average Train Loss: 56.4758
# Epoch 24, Average Test Loss: 57.4087
# Epoch 25, Average Train Loss: 56.0546
# Epoch 25, Average Test Loss: 58.1633
# Epoch 1, Average Train Loss: 198.4254
# Epoch 1, Average Test Loss: 128.7202
# Epoch 2, Average Train Loss: 117.1871
# Epoch 2, Average Test Loss: 108.6420
# Epoch 3, Average Train Loss: 105.3259
# Epoch 3, Average Test Loss: 99.5844
# Epoch 4, Average Train Loss: 99.3131
# Epoch 4, Average Test Loss: 97.2932
# Epoch 5, Average Train Loss: 94.8433
# Epoch 5, Average Test Loss: 92.6510
# Epoch 6, Average Train Loss: 90.6173
# Epoch 6, Average Test Loss: 91.2459
# Epoch 7, Average Train Loss: 85.9897
# Epoch 7, Average Test Loss: 84.7543
# Epoch 8, Average Train Loss: 82.6478
# Epoch 8, Average Test Loss: 81.3805
# Epoch 9, Average Train Loss: 80.5193
# Epoch 9, Average Test Loss: 80.4650
# Epoch 10, Average Train Loss: 78.2536
# Epoch 10, Average Test Loss: 76.8369
# Epoch 11, Average Train Loss: 76.0391
# Epoch 11, Average Test Loss: 75.9203
# Epoch 12, Average Train Loss: 74.7255
# Epoch 12, Average Test Loss: 73.8156
# Epoch 13, Average Train Loss: 72.6241
# Epoch 13, Average Test Loss: 71.8891
# Epoch 14, Average Train Loss: 70.4951
# Epoch 14, Average Test Loss: 69.7964
# Epoch 15, Average Train Loss: 69.1632
# Epoch 15, Average Test Loss: 68.5735
# Epoch 16, Average Train Loss: 67.1077
# Epoch 16, Average Test Loss: 66.7929
# Epoch 17, Average Train Loss: 65.1867
# Epoch 17, Average Test Loss: 65.5643
# Epoch 18, Average Train Loss: 63.3424
# Epoch 18, Average Test Loss: 63.4379
# Epoch 19, Average Train Loss: 62.2804
# Epoch 19, Average Test Loss: 62.3630
# Epoch 20, Average Train Loss: 60.9326
# Epoch 20, Average Test Loss: 60.9328
# Epoch 21, Average Train Loss: 59.7900
# Epoch 21, Average Test Loss: 60.5118
# Epoch 22, Average Train Loss: 59.1412
# Epoch 22, Average Test Loss: 59.5991
# Epoch 23, Average Train Loss: 58.3992
# Epoch 23, Average Test Loss: 59.3553
# Epoch 24, Average Train Loss: 57.6084
# Epoch 24, Average Test Loss: 58.5364
# Epoch 25, Average Train Loss: 57.5607
# Epoch 25, Average Test Loss: 58.8149
# Epoch 1, Average Train Loss: 209.7232
# Epoch 1, Average Test Loss: 141.3548
# Epoch 2, Average Train Loss: 125.9764
# Epoch 2, Average Test Loss: 115.6066
# Epoch 3, Average Train Loss: 112.3894
# Epoch 3, Average Test Loss: 107.7665
# Epoch 4, Average Train Loss: 106.0784
# Epoch 4, Average Test Loss: 105.2363
# Epoch 5, Average Train Loss: 100.9445
# Epoch 5, Average Test Loss: 98.9029
# Epoch 6, Average Train Loss: 96.8937
# Epoch 6, Average Test Loss: 95.1389
# Epoch 7, Average Train Loss: 92.7330
# Epoch 7, Average Test Loss: 90.5298
# Epoch 8, Average Train Loss: 89.8278
# Epoch 8, Average Test Loss: 89.6848
# Epoch 9, Average Train Loss: 88.3420
# Epoch 9, Average Test Loss: 86.2429
# Epoch 10, Average Train Loss: 85.5557
# Epoch 10, Average Test Loss: 83.7211
# Epoch 11, Average Train Loss: 83.0790
# Epoch 11, Average Test Loss: 81.2476
# Epoch 12, Average Train Loss: 80.7302
# Epoch 12, Average Test Loss: 80.9259
# Epoch 13, Average Train Loss: 78.0488
# Epoch 13, Average Test Loss: 77.0689
# Epoch 14, Average Train Loss: 75.3797
# Epoch 14, Average Test Loss: 75.1732
# Epoch 15, Average Train Loss: 73.1039
# Epoch 15, Average Test Loss: 73.2608
# Epoch 16, Average Train Loss: 71.0393
# Epoch 16, Average Test Loss: 70.0022
# Epoch 17, Average Train Loss: 68.8520
# Epoch 17, Average Test Loss: 68.3545
# Epoch 18, Average Train Loss: 67.0301
# Epoch 18, Average Test Loss: 67.0758
# Epoch 19, Average Train Loss: 65.4116
# Epoch 19, Average Test Loss: 65.7098
# Epoch 20, Average Train Loss: 64.8345
# Epoch 20, Average Test Loss: 65.2535
# Epoch 21, Average Train Loss: 63.6333
# Epoch 21, Average Test Loss: 63.9031
# Epoch 22, Average Train Loss: 62.8187
# Epoch 22, Average Test Loss: 62.8970
# Epoch 23, Average Train Loss: 61.7856
# Epoch 23, Average Test Loss: 61.8905
# Epoch 24, Average Train Loss: 60.8739
# Epoch 24, Average Test Loss: 61.6550
# Epoch 25, Average Train Loss: 60.3299
# Epoch 25, Average Test Loss: 60.7649
# Epoch 1, Average Train Loss: 220.7526
# Epoch 1, Average Test Loss: 127.2640
# Epoch 2, Average Train Loss: 119.3103
# Epoch 2, Average Test Loss: 112.9171
# Epoch 3, Average Train Loss: 111.0685
# Epoch 3, Average Test Loss: 108.6797
# Epoch 4, Average Train Loss: 106.8343
# Epoch 4, Average Test Loss: 104.3003
# Epoch 5, Average Train Loss: 103.9999
# Epoch 5, Average Test Loss: 102.3292
# Epoch 6, Average Train Loss: 101.4383
# Epoch 6, Average Test Loss: 99.5417
# Epoch 7, Average Train Loss: 98.4972
# Epoch 7, Average Test Loss: 97.8863
# Epoch 8, Average Train Loss: 96.5558
# Epoch 8, Average Test Loss: 94.9830
# ...
# Epoch 2, Average Test Loss: 175.3741
# Epoch 3, Average Train Loss: 178.9506
# Epoch 3, Average Test Loss: 172.2436
# Epoch 4, Average Train Loss: 179.6275
# Epoch 4, Average Test Loss: 173.3301
# Epoch 5, Average Train Loss: 178.0388
# Epoch 5, Average Test Loss: 172.3988
# Epoch 6, Average Train Loss: 177.9762
# Epoch 6, Average Test Loss: 172.5489
# Epoch 7, Average Train Loss: 177.7644
# Epoch 7, Average Test Loss: 171.8501
# Epoch 8, Average Train Loss: 177.6885
# Epoch 8, Average Test Loss: 171.9721
# Epoch 9, Average Train Loss: 177.7167
# Epoch 9, Average Test Loss: 171.2620
# Epoch 10, Average Train Loss: 177.2214
# Epoch 10, Average Test Loss: 171.1668
# Epoch 11, Average Train Loss: 177.6886
# Epoch 11, Average Test Loss: 172.6128
# Epoch 12, Average Train Loss: 177.6502
# Epoch 12, Average Test Loss: 171.8848
# Epoch 13, Average Train Loss: 177.6634
# Epoch 13, Average Test Loss: 174.2249
# Epoch 14, Average Train Loss: 178.4794
# Epoch 14, Average Test Loss: 171.9857
# Epoch 15, Average Train Loss: 177.6829
# Epoch 15, Average Test Loss: 173.3113
# Early stopping triggered at epoch 15!
# Epoch 1, Average Train Loss: 212.6865
# Epoch 1, Average Test Loss: 149.5684
# Epoch 2, Average Train Loss: 138.6780
# Epoch 2, Average Test Loss: 119.5663
# Epoch 3, Average Train Loss: 115.2292
# Epoch 3, Average Test Loss: 106.3885
# Epoch 4, Average Train Loss: 102.4609
# Epoch 4, Average Test Loss: 98.6747
# Epoch 5, Average Train Loss: 94.0623
# Epoch 5, Average Test Loss: 89.8731
# Epoch 6, Average Train Loss: 88.2191
# Epoch 6, Average Test Loss: 86.3962
# Epoch 7, Average Train Loss: 85.3756
# Epoch 7, Average Test Loss: 82.8490
# Epoch 8, Average Train Loss: 81.8170
# Epoch 8, Average Test Loss: 78.8426
# Epoch 9, Average Train Loss: 80.2782
# Epoch 9, Average Test Loss: 80.2255
# Epoch 10, Average Train Loss: 77.4035
# Epoch 10, Average Test Loss: 76.6606
# Epoch 11, Average Train Loss: 75.7473
# Epoch 11, Average Test Loss: 75.5098
# Epoch 12, Average Train Loss: 74.2447
# Epoch 12, Average Test Loss: 74.9689
# Epoch 13, Average Train Loss: 73.4407
# Epoch 13, Average Test Loss: 75.8232
# Epoch 14, Average Train Loss: 72.5077
# Epoch 14, Average Test Loss: 74.0278
# Epoch 15, Average Train Loss: 71.7555
# Epoch 15, Average Test Loss: 72.5880
# Epoch 16, Average Train Loss: 70.9792
# Epoch 16, Average Test Loss: 70.9878
# Epoch 17, Average Train Loss: 70.0303
# Epoch 17, Average Test Loss: 72.8653
# Epoch 18, Average Train Loss: 69.7687
# Epoch 18, Average Test Loss: 70.2496
# Epoch 19, Average Train Loss: 69.7115
# Epoch 19, Average Test Loss: 70.0634
# Epoch 20, Average Train Loss: 69.4500
# Epoch 20, Average Test Loss: 71.3871
# Epoch 21, Average Train Loss: 68.6809
# Epoch 21, Average Test Loss: 68.7092
# Epoch 22, Average Train Loss: 68.7878
# Epoch 22, Average Test Loss: 68.7958
# Epoch 23, Average Train Loss: 68.4086
# Epoch 23, Average Test Loss: 67.6148
# Epoch 24, Average Train Loss: 67.4854
# Epoch 24, Average Test Loss: 68.1766
# Epoch 25, Average Train Loss: 68.1791
# Epoch 25, Average Test Loss: 69.0594
# Epoch 1, Average Train Loss: 212.3228
# Epoch 1, Average Test Loss: 154.4548
# Epoch 2, Average Train Loss: 133.0749
# Epoch 2, Average Test Loss: 118.0613
# Epoch 3, Average Train Loss: 113.3036
# Epoch 3, Average Test Loss: 107.7035
# Epoch 4, Average Train Loss: 103.4191
# Epoch 4, Average Test Loss: 98.5199
# Epoch 5, Average Train Loss: 94.1515
# Epoch 5, Average Test Loss: 91.9610
# Epoch 6, Average Train Loss: 90.3228
# Epoch 6, Average Test Loss: 86.8423
# Epoch 7, Average Train Loss: 83.5314
# Epoch 7, Average Test Loss: 82.6939
# Epoch 8, Average Train Loss: 80.4424
# Epoch 8, Average Test Loss: 80.5135
# Epoch 9, Average Train Loss: 76.2432
# Epoch 9, Average Test Loss: 75.4778
# Epoch 10, Average Train Loss: 73.4101
# Epoch 10, Average Test Loss: 72.4647
# Epoch 11, Average Train Loss: 71.4143
# Epoch 11, Average Test Loss: 72.4038
# Epoch 12, Average Train Loss: 70.7513
# Epoch 12, Average Test Loss: 70.8979
# Epoch 13, Average Train Loss: 69.2268
# Epoch 13, Average Test Loss: 69.1794
# Epoch 14, Average Train Loss: 68.2870
# Epoch 14, Average Test Loss: 69.6500
# Epoch 15, Average Train Loss: 68.2735
# Epoch 15, Average Test Loss: 68.0099
# Epoch 16, Average Train Loss: 67.1098
# Epoch 16, Average Test Loss: 69.0506
# Epoch 17, Average Train Loss: 66.4739
# Epoch 17, Average Test Loss: 66.4791
# Epoch 18, Average Train Loss: 64.4929
# Epoch 18, Average Test Loss: 65.1372
# Epoch 19, Average Train Loss: 64.8812
# Epoch 19, Average Test Loss: 66.6436
# Epoch 20, Average Train Loss: 63.8856
# Epoch 20, Average Test Loss: 63.9760
# Epoch 21, Average Train Loss: 63.6613
# Epoch 21, Average Test Loss: 64.2813
# Epoch 22, Average Train Loss: 63.6711
# Epoch 22, Average Test Loss: 64.6909
# Epoch 23, Average Train Loss: 63.0966
# Epoch 23, Average Test Loss: 63.5930
# Epoch 24, Average Train Loss: 63.4805
# Epoch 24, Average Test Loss: 62.9267
# Epoch 25, Average Train Loss: 62.1237
# Epoch 25, Average Test Loss: 62.3847
# Epoch 1, Average Train Loss: 198.5089
# Epoch 1, Average Test Loss: 117.7689
# Epoch 2, Average Train Loss: 108.0672
# Epoch 2, Average Test Loss: 99.5511
# Epoch 3, Average Train Loss: 93.0729
# Epoch 3, Average Test Loss: 87.7501
# Epoch 4, Average Train Loss: 84.0925
# Epoch 4, Average Test Loss: 80.9137
# Epoch 5, Average Train Loss: 78.3639
# Epoch 5, Average Test Loss: 75.9956
# Epoch 6, Average Train Loss: 74.2511
# Epoch 6, Average Test Loss: 73.7257
# Epoch 7, Average Train Loss: 70.8746
# Epoch 7, Average Test Loss: 69.7748
# Epoch 8, Average Train Loss: 68.7507
# Epoch 8, Average Test Loss: 67.1479
# Epoch 9, Average Train Loss: 66.0884
# Epoch 9, Average Test Loss: 64.9548
# Epoch 10, Average Train Loss: 64.1035
# Epoch 10, Average Test Loss: 63.6637
# Epoch 11, Average Train Loss: 62.3990
# Epoch 11, Average Test Loss: 63.0832
# Epoch 12, Average Train Loss: 61.4388
# Epoch 12, Average Test Loss: 61.5579
# Epoch 13, Average Train Loss: 60.1720
# Epoch 13, Average Test Loss: 61.1731
# Epoch 14, Average Train Loss: 59.3640
# Epoch 14, Average Test Loss: 60.3021
# Epoch 15, Average Train Loss: 58.3934
# Epoch 15, Average Test Loss: 59.3055
# Epoch 16, Average Train Loss: 57.9077
# Epoch 16, Average Test Loss: 58.4670
# Epoch 17, Average Train Loss: 57.1607
# Epoch 17, Average Test Loss: 58.0131
# Epoch 18, Average Train Loss: 56.6166
# Epoch 18, Average Test Loss: 57.6070
# Epoch 19, Average Train Loss: 56.0999
# Epoch 19, Average Test Loss: 57.6447
# Epoch 20, Average Train Loss: 55.3233
# Epoch 20, Average Test Loss: 56.2046
# Epoch 21, Average Train Loss: 55.0586
# Epoch 21, Average Test Loss: 56.3488
# Epoch 22, Average Train Loss: 54.4027
# Epoch 22, Average Test Loss: 56.0816
# Epoch 23, Average Train Loss: 53.9693
# Epoch 23, Average Test Loss: 56.0150
# Epoch 24, Average Train Loss: 53.8724
# Epoch 24, Average Test Loss: 55.6115
# Epoch 25, Average Train Loss: 53.2412
# Epoch 25, Average Test Loss: 54.2882
# Epoch 1, Average Train Loss: 199.8364
# Epoch 1, Average Test Loss: 123.7662
# Epoch 2, Average Train Loss: 115.6636
# Epoch 2, Average Test Loss: 108.7355
# Epoch 3, Average Train Loss: 105.3668
# Epoch 3, Average Test Loss: 100.1687
# Epoch 4, Average Train Loss: 96.2446
# Epoch 4, Average Test Loss: 93.1081
# Epoch 5, Average Train Loss: 90.2768
# Epoch 5, Average Test Loss: 88.1605
# Epoch 6, Average Train Loss: 84.4837
# Epoch 6, Average Test Loss: 82.6877
# Epoch 7, Average Train Loss: 79.8243
# Epoch 7, Average Test Loss: 78.2888
# Epoch 8, Average Train Loss: 76.5521
# Epoch 8, Average Test Loss: 75.7497
# Epoch 9, Average Train Loss: 73.8286
# Epoch 9, Average Test Loss: 73.4950
# Epoch 10, Average Train Loss: 71.7105
# Epoch 10, Average Test Loss: 71.4048
# Epoch 11, Average Train Loss: 69.7634
# Epoch 11, Average Test Loss: 69.1042
# Epoch 12, Average Train Loss: 67.6592
# Epoch 12, Average Test Loss: 67.2813
# Epoch 13, Average Train Loss: 65.8618
# Epoch 13, Average Test Loss: 65.6563
# Epoch 14, Average Train Loss: 64.6414
# Epoch 14, Average Test Loss: 64.3670
# Epoch 15, Average Train Loss: 63.2387
# Epoch 15, Average Test Loss: 63.4583
# Epoch 16, Average Train Loss: 62.2080
# Epoch 16, Average Test Loss: 61.9982
# Epoch 17, Average Train Loss: 61.3193
# Epoch 17, Average Test Loss: 61.3562
# Epoch 18, Average Train Loss: 60.3193
# Epoch 18, Average Test Loss: 60.8098
# Epoch 19, Average Train Loss: 59.3395
# Epoch 19, Average Test Loss: 59.7553
# Epoch 20, Average Train Loss: 59.0496
# Epoch 20, Average Test Loss: 59.0429
# Epoch 21, Average Train Loss: 58.1194
# Epoch 21, Average Test Loss: 58.1893
# Epoch 22, Average Train Loss: 57.4560
# Epoch 22, Average Test Loss: 58.1840
# Epoch 23, Average Train Loss: 56.7664
# Epoch 23, Average Test Loss: 57.4975
# Epoch 24, Average Train Loss: 56.3792
# Epoch 24, Average Test Loss: 57.3925
# Epoch 25, Average Train Loss: 55.8064
# Epoch 25, Average Test Loss: 57.6356
# Epoch 1, Average Train Loss: 386.7862
# Epoch 1, Average Test Loss: 170.3684
# Epoch 2, Average Train Loss: 159.3755
# Epoch 2, Average Test Loss: 139.5195
# Epoch 3, Average Train Loss: 126.7437
# Epoch 3, Average Test Loss: 117.6469
# Epoch 4, Average Train Loss: 113.7668
# Epoch 4, Average Test Loss: 107.9726
# Epoch 5, Average Train Loss: 104.6893
# Epoch 5, Average Test Loss: 101.1267
# Epoch 6, Average Train Loss: 98.0138
# Epoch 6, Average Test Loss: 94.3527
# Epoch 7, Average Train Loss: 92.2894
# Epoch 7, Average Test Loss: 91.3151
# Epoch 8, Average Train Loss: 88.4377
# Epoch 8, Average Test Loss: 86.2422
# Epoch 9, Average Train Loss: 84.9530
# Epoch 9, Average Test Loss: 83.7565
# Epoch 10, Average Train Loss: 81.9378
# Epoch 10, Average Test Loss: 80.6082
# Epoch 11, Average Train Loss: 79.9204
# Epoch 11, Average Test Loss: 78.9009
# Epoch 12, Average Train Loss: 77.4523
# Epoch 12, Average Test Loss: 76.7131
# Epoch 13, Average Train Loss: 75.2291
# Epoch 13, Average Test Loss: 75.2796
# Epoch 14, Average Train Loss: 74.0018
# Epoch 14, Average Test Loss: 73.4139
# Epoch 15, Average Train Loss: 72.1161
# Epoch 15, Average Test Loss: 72.0920
# Epoch 16, Average Train Loss: 71.1445
# Epoch 16, Average Test Loss: 70.1768
# Epoch 17, Average Train Loss: 69.0937
# Epoch 17, Average Test Loss: 68.7561
# Epoch 18, Average Train Loss: 67.5045
# Epoch 18, Average Test Loss: 67.5700
# Epoch 19, Average Train Loss: 66.2043
# Epoch 19, Average Test Loss: 66.5089
# Epoch 20, Average Train Loss: 65.2000
# Epoch 20, Average Test Loss: 65.2690
# Epoch 21, Average Train Loss: 64.0437
# Epoch 21, Average Test Loss: 64.0829
# Epoch 22, Average Train Loss: 63.3389
# Epoch 22, Average Test Loss: 63.7662
# Epoch 23, Average Train Loss: 62.4470
# Epoch 23, Average Test Loss: 63.2147
# Epoch 24, Average Train Loss: 62.0006
# Epoch 24, Average Test Loss: 62.4272
# Epoch 25, Average Train Loss: 61.2445
# Epoch 25, Average Test Loss: 61.8815
# Epoch 1, Average Train Loss: 348.2353
# Epoch 1, Average Test Loss: 173.9178
# Epoch 2, Average Train Loss: 157.0184
# Epoch 2, Average Test Loss: 134.1140
# Epoch 3, Average Train Loss: 126.0395
# Epoch 3, Average Test Loss: 119.3615
# Epoch 4, Average Train Loss: 116.2043
# Epoch 4, Average Test Loss: 111.1232
# Epoch 5, Average Train Loss: 110.3835
# Epoch 5, Average Test Loss: 107.2044
# Epoch 6, Average Train Loss: 106.9710
# Epoch 6, Average Test Loss: 104.7551
# Epoch 7, Average Train Loss: 103.8040
# Epoch 7, Average Test Loss: 101.9002
# Epoch 8, Average Train Loss: 100.8582
# Epoch 8, Average Test Loss: 99.3622
# Epoch 9, Average Train Loss: 98.0248
# Epoch 9, Average Test Loss: 97.4108
# Epoch 10, Average Train Loss: 95.2129
# Epoch 10, Average Test Loss: 93.8534
# Epoch 11, Average Train Loss: 93.1406
# Epoch 11, Average Test Loss: 91.9222
# Epoch 12, Average Train Loss: 91.3023
# Epoch 12, Average Test Loss: 91.9454
# Epoch 13, Average Train Loss: 89.6214
# Epoch 13, Average Test Loss: 89.1988
# Epoch 14, Average Train Loss: 87.9428
# Epoch 14, Average Test Loss: 87.0161
# Epoch 15, Average Train Loss: 86.6360
# Epoch 15, Average Test Loss: 86.3348
# Epoch 16, Average Train Loss: 85.0959
# Epoch 16, Average Test Loss: 84.4023
# Epoch 17, Average Train Loss: 83.7153
# Epoch 17, Average Test Loss: 83.1836
# Epoch 18, Average Train Loss: 82.4664
# Epoch 18, Average Test Loss: 82.2829
# Epoch 19, Average Train Loss: 81.5245
# Epoch 19, Average Test Loss: 81.9343
# Epoch 20, Average Train Loss: 80.5376
# Epoch 20, Average Test Loss: 80.2734
# Epoch 21, Average Train Loss: 79.6131
# Epoch 21, Average Test Loss: 79.3259
# Epoch 22, Average Train Loss: 78.6937
# Epoch 22, Average Test Loss: 78.8265
# Epoch 23, Average Train Loss: 77.9223
# Epoch 23, Average Test Loss: 78.5566
# Epoch 24, Average Train Loss: 77.3988
# Epoch 24, Average Test Loss: 77.1766
# Epoch 25, Average Train Loss: 76.5739
# Epoch 25, Average Test Loss: 76.2545
# Epoch 1, Average Train Loss: 358.8164
# Epoch 1, Average Test Loss: 213.0204
# Epoch 2, Average Train Loss: 183.8072
# Epoch 2, Average Test Loss: 160.0070
# Epoch 3, Average Train Loss: 144.9380
# Epoch 3, Average Test Loss: 129.2278
# Epoch 4, Average Train Loss: 124.6646
# Epoch 4, Average Test Loss: 120.6126
# Epoch 5, Average Train Loss: 117.6373
# Epoch 5, Average Test Loss: 114.7316
# Epoch 6, Average Train Loss: 112.7077
# Epoch 6, Average Test Loss: 110.5745
# Epoch 7, Average Train Loss: 109.5343
# Epoch 7, Average Test Loss: 107.2224
# Epoch 8, Average Train Loss: 107.0046
# Epoch 8, Average Test Loss: 105.3829
# Epoch 9, Average Train Loss: 104.9785
# Epoch 9, Average Test Loss: 103.8547
# Epoch 10, Average Train Loss: 103.0538
# Epoch 10, Average Test Loss: 102.1076
# Epoch 11, Average Train Loss: 100.9362
# Epoch 11, Average Test Loss: 99.8810
# Epoch 12, Average Train Loss: 99.6580
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-99c25d9911fb> in <cell line: 29>()
#      41     for epoch in range(1, num_epochs + 1):
#      42         train(model, optimizer, train_loader, device, epoch)
# ---> 43         current_val_loss = validate(model, test_loader, device, epoch)
#      44
#      45         if current_val_loss is not None:  # Make sure val_loss is not None
#
# <ipython-input-6-84bddefaf0fb> in validate(model, test_loader, device, epoch)
#      17     test_loss = 0
#      18     with torch.no_grad():
# ---> 19         for data in test_loader:
#      20             data = data.to(device)
#      21             recon, mu, logvar = model(data)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     672     def _next_data(self):
#     673         index = self._next_index()  # may raise StopIteration
# --> 674         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675         if self._pin_memory:
#     676             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# <ipython-input-3-7b6e2ec886ba> in __getitem__(self, idx)
#       9     def __getitem__(self, idx):
#      10         img_path = self.image_paths[idx]
# ---> 11         image = Image.open(img_path).convert('L')  # Convert to grayscale
#      12         if self.transform:
#      13             image = self.transform(image)
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3225
#    3226     if filename:
# -> 3227         fp = builtins.open(filename, "rb")
#    3228         exclusive_fp = True
#    3229
#
# KeyboardInterrupt:

# %% [markdown]
# Ive noticed that sometimes the loss value is NaN. This could be because the learning rate is too high in this specific config.
#
#
# ## Note:
# My grid search stopped running because for some reason google collab started multiple sessions for one other notebook. This means that the run was interupted and there is not enough time for another one. While looking at the losses for each epoch i found that the smallest loss at 10 epochs was around 65. This is very similar to a short test I was running in the main file for 10 epochs so I will keep the hyperparameters the same for now.
